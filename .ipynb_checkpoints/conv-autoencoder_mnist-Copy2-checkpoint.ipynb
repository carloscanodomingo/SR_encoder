# %% [markdown]
# STAT 453: Deep Learning (Spring 2021)
# Instructor: Sebastian Raschka (sraschka@wisc.edu)
#
# Course website: http://pages.stat.wisc.edu/~sraschka/teaching/stat453-ss2021/
# GitHub repository: https://github.com/rasbt/stat453-deep-learning-ss21
#
# ---

# %% [markdown]
# # Convolutional Autoencoder

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy

# %% [markdown]
# #### Import utility functions

# %%
from data_loader_helper import get_dataloaders_mnist, read_sr_data, transform_data
from helper_utils import set_deterministic, set_all_seeds
from helper_train import train_autoencoder_v1, get_freq_est, get_data_complete, train_vae_v1
from helper_plotting import plot_latent_space_with_labels, plot_frequencies, plot_loss, plot_freq_loss, plot_season, plot_training_loss, plot_cases

# %% [markdown]
# #### Weight and bias

# %%
root ='D:\GIT\pytorch\pytorch-vq-vae'
data_path = '\\data'
fit_sr = '\\SR_table_DL.mat'
filepath = root+ data_path + fit_sr;

# %%
##########################
### SETTINGS
##########################

# Device
DEVICE_CPU = "cpu"
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('Device:', DEVICE)

# Hyperparameters
RANDOM_SEED = 123
LEARNING_RATE = 0.001
BATCH_SIZE = 32 * 5
NUM_EPOCHS = 2000
num_hiddens = 64
latent_dim = 10
kernel_size = 64
regression_hidden = 128
freq_mult = 100
dropout = 0.0
# Out:
# Device: cuda

# %%
import wandb

config = {
    "learning_rate": LEARNING_RATE,
    "epochs": NUM_EPOCHS,
    "batch_size": BATCH_SIZE,
    "kernel_size": kernel_size,
    "num_hiddens": num_hiddens,
    "lantent_dim": latent_dim,
    "regression_hidden":regression_hidden,
    "freq_mult": freq_mult,
     "dropout": dropout,
    "best_perc": 20,
    "type": "NO_RAW"
}

# %%
set_deterministic
set_all_seeds(RANDOM_SEED)

# %% [markdown]
# ## Dataset

# %%
##########################
### Dataset
##########################

train_loader, test_loader = get_dataloaders_mnist(filepath ,batch_size = BATCH_SIZE, worst_case = 0, lorentz = False)

# %%
train_loader_worst, test_loader_worst = get_dataloaders_mnist(filepath, batch_size = BATCH_SIZE, worst_case = False, lorentz = False)

# %%
# Checking the dataset
print('Training Set:\n')
for data_raw, data_lorentz,values_freq, labels in train_loader:  
    print('data raw dimensions:', data_raw.size())
    print('data lorentz dimensions:', data_lorentz.size())
    print('Freq  dimensions:', values_freq.size())
    print('label dimensions:', labels.size())
    NUM_CLASSES = len(numpy.unique(labels))
    print(data_raw[:10])
    break
    
print(NUM_CLASSES)
# Checking the dataset
print('\nTesting Set:')
for data_raw, data_lorentz,values_freq,  labels in test_loader:  
    print('data raw dimensions:', data_raw.size())
    print('data lorentz dimensions:', data_lorentz.size())
    print('Freq  dimensions:', values_freq.size())
    print('label dimensions:', labels.size())
    break
# Out:
# Training Set:
#
# data raw dimensions: torch.Size([320, 1, 256])
# data lorentz dimensions: torch.Size([320, 1, 256])
# Freq  dimensions: torch.Size([320, 6])
# label dimensions: torch.Size([320])
# tensor([[[0.2379, 0.2878, 0.3154,  ..., 0.1923, 0.0866, 0.0865]],
#
#         [[0.2840, 0.2837, 0.3718,  ..., 0.0938, 0.0233, 0.0831]],
#
#         [[0.1589, 0.1931, 0.2832,  ..., 0.1403, 0.0314, 0.0714]],
#
#         ...,
#
#         [[0.2890, 0.2789, 0.2859,  ..., 0.2205, 0.1143, 0.1372]],
#
#         [[0.4502, 0.4893, 0.4730,  ..., 0.1715, 0.0650, 0.0884]],
#
#         [[0.2155, 0.2490, 0.3187,  ..., 0.1434, 0.0398, 0.0667]]])
# 4
#
# Testing Set:
# data raw dimensions: torch.Size([320, 1, 256])
# data lorentz dimensions: torch.Size([320, 1, 256])
# Freq  dimensions: torch.Size([320, 6])
# label dimensions: torch.Size([320])

# %% [markdown]
# ## Model

# %%
##########################
### MODEL
##########################


class Reshape(nn.Module):
    def __init__(self, *args):
        super().__init__()
        self.shape = args

    def forward(self, x):
        return x.view(self.shape)


class Trim(nn.Module):
    def __init__(self, *args):
        super().__init__()

    def forward(self, x):
        return x[:, :, :256]
class VAE(nn.Module):
    def __init__(self, num_hiddens, kernel_size, data_len, latent_dim, regression_hidden, dropout):
        super().__init__()
        
        self.encoder = nn.Sequential( #784
                nn.Conv1d(in_channels=1,
                      out_channels=num_hiddens // 2,
                      kernel_size=kernel_size, stride=2, padding = kernel_size  // 2 - 1, bias=False),
                nn.LeakyReLU(0.01),
                 
                nn.Dropout(dropout),
                nn.Conv1d(in_channels=num_hiddens // 2,
                      out_channels=num_hiddens,
                      kernel_size=kernel_size // 2, stride=2, padding = kernel_size  // 2 // 2 - 1, bias=False),
                nn.LeakyReLU(0.01),
                nn.Conv1d(in_channels=num_hiddens,
                      out_channels=num_hiddens,
                      kernel_size=kernel_size // 4, stride=2, padding = kernel_size  // 4 // 2 - 1, bias=False),
                nn.LeakyReLU(0.01),
                nn.Flatten(),
        )
        self.z_mean = torch.nn.Linear(num_hiddens * (data_len // (2 ** 3)), latent_dim)
        self.z_log_var = torch.nn.Linear(num_hiddens * (data_len // (2 ** 3)), latent_dim)
        
        self.regresion = nn.Sequential(
                nn.Linear(latent_dim , regression_hidden),
                nn.Linear(regression_hidden , 6),
                nn.Sigmoid()
        )
        self.decoder = nn.Sequential(
                torch.nn.Linear(latent_dim, num_hiddens * (data_len // (2 ** 3))),
                Reshape(-1, num_hiddens, (data_len // (2 ** 3))),
                nn.ConvTranspose1d(in_channels=num_hiddens,
                      out_channels=num_hiddens,
                      kernel_size=kernel_size // 4, stride=2, padding = kernel_size // 4 // 2 - 1, bias=False),
                nn.LeakyReLU(0.01),
                nn.ConvTranspose1d(in_channels=num_hiddens,
                      out_channels=num_hiddens // 2,
                      kernel_size=kernel_size // 2, stride=2, padding = kernel_size // 2 // 2 - 1, bias=False),
                nn.LeakyReLU(0.01),
                nn.ConvTranspose1d(in_channels=num_hiddens // 2,
                      out_channels=1,
                      kernel_size=kernel_size , stride=2, padding = kernel_size  // 2 - 1, bias=False),
                nn.LeakyReLU(0.01),
                nn.Dropout(dropout),
                Trim(),  # 1x29x29 -> 1x28x28
                nn.Sigmoid()
                )
    def encoding_fn(self, x):
        x = self.encoder(x)
        z_mean, z_log_var = self.z_mean(x), self.z_log_var(x)
        encoded = self.reparameterize(z_mean, z_log_var)
        return encoded
    def reparameterize(self, z_mu, z_log_var):
        eps = torch.randn(z_mu.size(0), z_mu.size(1), device=z_mu.device)
        z = z_mu + eps * torch.exp(z_log_var/2.) 
        return z
    def latent_sample(self, z_mu, z_log_var):
        # the reparameterization trick
        std = z_log_var.mul(0.5).exp_()
        eps = torch.empty_like(std).normal_()
        return eps.mul(std).add_(z_mu)

    def forward(self, x):
        x = self.encoder(x)
        z_mean, z_log_var = self.z_mean(x), self.z_log_var(x)
        encoded = self.latent_sample(z_mean, z_log_var)
        freq = self.regresion(encoded)#torch.cat((z_mean, z_log_var), dim = 1))
        decoded = self.decoder(encoded)
        return encoded, z_mean, z_log_var,freq, decoded

    
class AutoEncoder(nn.Module):
    def __init__(self, num_hiddens, kernel_size, data_len, latent_dim, regression_hidden, dropout):
        super().__init__()
        
        self.encoder = nn.Sequential( #784
                nn.Conv1d(in_channels=1,
                      out_channels=num_hiddens // 2,
                      kernel_size=kernel_size, stride=2, padding = kernel_size  // 2 - 1, bias=False),
                nn.LeakyReLU(0.01),
                 
                nn.Dropout(dropout),
                nn.Conv1d(in_channels=num_hiddens // 2,
                      out_channels=num_hiddens,
                      kernel_size=kernel_size // 2, stride=2, padding = kernel_size  // 2 // 2 - 1, bias=False),
                nn.LeakyReLU(0.01),
                nn.Conv1d(in_channels=num_hiddens,
                      out_channels=num_hiddens,
                      kernel_size=kernel_size // 4, stride=2, padding = kernel_size  // 4 // 2 - 1, bias=False),
                nn.LeakyReLU(0.01),
                nn.Flatten(),
                nn.Linear(num_hiddens * (data_len // (2 ** 3)), latent_dim),
        )
        self.regresion = nn.Sequential(
                nn.Linear(latent_dim , regression_hidden),
                nn.Linear(regression_hidden , 6),
                nn.Sigmoid()
        )
        self.decoder = nn.Sequential(
                torch.nn.Linear(latent_dim, num_hiddens * (data_len // (2 ** 3))),
                Reshape(-1, num_hiddens, (data_len // (2 ** 3))),
                nn.ConvTranspose1d(in_channels=num_hiddens,
                      out_channels=num_hiddens,
                      kernel_size=kernel_size // 4, stride=2, padding = kernel_size // 4 // 2 - 1, bias=False),
                nn.LeakyReLU(0.01),
                nn.ConvTranspose1d(in_channels=num_hiddens,
                      out_channels=num_hiddens // 2,
                      kernel_size=kernel_size // 2, stride=2, padding = kernel_size // 2 // 2 - 1, bias=False),
                nn.LeakyReLU(0.01),
                nn.ConvTranspose1d(in_channels=num_hiddens // 2,
                      out_channels=1,
                      kernel_size=kernel_size , stride=2, padding = kernel_size  // 2 - 1, bias=False),
                nn.LeakyReLU(0.01),
                nn.Dropout(dropout),
                Trim(),  # 1x29x29 -> 1x28x28
                nn.Sigmoid()
                )
    def forward(self, x):
        x = self.encoder(x)
        x_freq = self.regresion(x)
        x = self.decoder(x)
        return x, x_freq

# %%
data_len = 256
SWEEP = 0
wandb.init(project="AutoEncoder", notes="add dropout",tags=["VAE", "paper5"],config=config)
# Out:
# Finishing last run (ID:alk7fk0g) before initializing another...
# <br/>Waiting for W&B process to finish, PID 2340... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>█▆▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_ae</td><td>█▄▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▂▂▁▁▁▂▁▁▁▁▁▂▁▁▁▁</td></tr><tr><td>loss_freq</td><td>█▅▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_kl</td><td>█▅▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>worst_loss</td><td>█▄▄▄▃▂▂▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>worst_loss_ae</td><td>█▄▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▂▂</td></tr><tr><td>worst_loss_freq</td><td>█▅▅▅▃▃▃▄▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>0.00481</td></tr><tr><td>loss_ae</td><td>0.00119</td></tr><tr><td>loss_freq</td><td>0.00251</td></tr><tr><td>loss_kl</td><td>0.00251</td></tr><tr><td>worst_loss</td><td>0.00643</td></tr><tr><td>worst_loss_ae</td><td>0.00233</td></tr><tr><td>worst_loss_freq</td><td>0.0041</td></tr></table>
# </div></div>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">hearty-armadillo-118</strong>: <a href="https://wandb.ai/carcandom/AutoEncoder/runs/alk7fk0g" target="_blank">https://wandb.ai/carcandom/AutoEncoder/runs/alk7fk0g</a><br/>
# Find logs at: <code>.\wandb\run-20220301_200205-alk7fk0g\logs</code><br/>
# Successfully finished last run (ID:alk7fk0g). Initializing new run:<br/>
# wandb: wandb version 0.12.11 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/carcandom/AutoEncoder/runs/1otsmo2l" target="_blank">giddy-water-119</a></strong> to <a href="https://wandb.ai/carcandom/AutoEncoder" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/carcandom/AutoEncoder/runs/1otsmo2l?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
 from torchvision import models
from torchsummary import summary
set_all_seeds(RANDOM_SEED)

model = VAE(num_hiddens = num_hiddens, kernel_size = kernel_size, data_len = data_len, latent_dim = latent_dim, regression_hidden = regression_hidden, dropout = dropout)
model.to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)  
summary(model, (1,256), batch_size=-1, device='cuda')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1              [-1, 32, 128]           2,048
#          LeakyReLU-2              [-1, 32, 128]               0
#            Dropout-3              [-1, 32, 128]               0
#             Conv1d-4               [-1, 64, 64]          65,536
#          LeakyReLU-5               [-1, 64, 64]               0
#             Conv1d-6               [-1, 64, 32]          65,536
#          LeakyReLU-7               [-1, 64, 32]               0
#            Flatten-8                 [-1, 2048]               0
#             Linear-9                   [-1, 10]          20,490
#            Linear-10                   [-1, 10]          20,490
#            Linear-11                  [-1, 128]           1,408
#            Linear-12                    [-1, 6]             774
#           Sigmoid-13                    [-1, 6]               0
#            Linear-14                 [-1, 2048]          22,528
#           Reshape-15               [-1, 64, 32]               0
#   ConvTranspose1d-16               [-1, 64, 64]          65,536
#         LeakyReLU-17               [-1, 64, 64]               0
#   ConvTranspose1d-18              [-1, 32, 128]          65,536
#         LeakyReLU-19              [-1, 32, 128]               0
#   ConvTranspose1d-20               [-1, 1, 256]           2,048
#         LeakyReLU-21               [-1, 1, 256]               0
#           Dropout-22               [-1, 1, 256]               0
#              Trim-23               [-1, 1, 256]               0
#           Sigmoid-24               [-1, 1, 256]               0
# ================================================================
# Total params: 331,930
# Trainable params: 331,930
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.37
# Params size (MB): 1.27
# Estimated Total Size (MB): 1.64
# ----------------------------------------------------------------

# %%
epoch = NUM_EPOCHS
log_dict = train_vae_v1(num_epochs=epoch, model=model, 
                            optimizer=optimizer, device=DEVICE, freq_mult = freq_mult,
                            train_loader=train_loader,
                            worst_case_loader = train_loader_worst,
                            skip_epoch_stats=True,
                            logging_interval=200, wandb = wandb)
# Out:
# Time elapsed: 0.06 min
# Epocah: 001/2000 | Loss: 1.4147 | Loss_freq: 1.3814 | Loss_ae: 0.0137 | kl_div 0.0195 | Worst_Loss: 0.1652 | Worst_Loss_freq: 0.0127 | Worst_Loss_ae: 0.1779 |
# Time elapsed: 0.12 min
# Epocah: 002/2000 | Loss: 0.3102 | Loss_freq: 0.2722 | Loss_ae: 0.0086 | kl_div 0.0294 | Worst_Loss: 0.0286 | Worst_Loss_freq: 0.0080 | Worst_Loss_ae: 0.0366 |
# Time elapsed: 0.19 min
# Epocah: 003/2000 | Loss: 0.2130 | Loss_freq: 0.1729 | Loss_ae: 0.0065 | kl_div 0.0336 | Worst_Loss: 0.0233 | Worst_Loss_freq: 0.0074 | Worst_Loss_ae: 0.0307 |
# Time elapsed: 0.25 min
# Epocah: 004/2000 | Loss: 0.1612 | Loss_freq: 0.1167 | Loss_ae: 0.0057 | kl_div 0.0388 | Worst_Loss: 0.0167 | Worst_Loss_freq: 0.0061 | Worst_Loss_ae: 0.0228 |
# Time elapsed: 0.31 min
# Epocah: 005/2000 | Loss: 0.0972 | Loss_freq: 0.0559 | Loss_ae: 0.0037 | kl_div 0.0377 | Worst_Loss: 0.0139 | Worst_Loss_freq: 0.0040 | Worst_Loss_ae: 0.0179 |
# Time elapsed: 0.37 min
# Epocah: 006/2000 | Loss: 0.1650 | Loss_freq: 0.1278 | Loss_ae: 0.0024 | kl_div 0.0348 | Worst_Loss: 0.0197 | Worst_Loss_freq: 0.0034 | Worst_Loss_ae: 0.0231 |
# Time elapsed: 0.43 min
# Epocah: 007/2000 | Loss: 0.1082 | Loss_freq: 0.0679 | Loss_ae: 0.0029 | kl_div 0.0374 | Worst_Loss: 0.0130 | Worst_Loss_freq: 0.0030 | Worst_Loss_ae: 0.0160 |
# Time elapsed: 0.49 min
# Epocah: 008/2000 | Loss: 0.1097 | Loss_freq: 0.0709 | Loss_ae: 0.0019 | kl_div 0.0369 | Worst_Loss: 0.0138 | Worst_Loss_freq: 0.0025 | Worst_Loss_ae: 0.0163 |
# Time elapsed: 0.55 min
# Epocah: 009/2000 | Loss: 0.1156 | Loss_freq: 0.0757 | Loss_ae: 0.0029 | kl_div 0.0371 | Worst_Loss: 0.0138 | Worst_Loss_freq: 0.0027 | Worst_Loss_ae: 0.0164 |
# Time elapsed: 0.61 min
# Epocah: 010/2000 | Loss: 0.1345 | Loss_freq: 0.0945 | Loss_ae: 0.0030 | kl_div 0.0371 | Worst_Loss: 0.0131 | Worst_Loss_freq: 0.0021 | Worst_Loss_ae: 0.0153 |
# Time elapsed: 0.67 min
# Epocah: 011/2000 | Loss: 0.1039 | Loss_freq: 0.0651 | Loss_ae: 0.0024 | kl_div 0.0363 | Worst_Loss: 0.0130 | Worst_Loss_freq: 0.0021 | Worst_Loss_ae: 0.0151 |
# Time elapsed: 0.73 min
# Epocah: 012/2000 | Loss: 0.2055 | Loss_freq: 0.1685 | Loss_ae: 0.0031 | kl_div 0.0339 | Worst_Loss: 0.0200 | Worst_Loss_freq: 0.0022 | Worst_Loss_ae: 0.0222 |
# Time elapsed: 0.80 min
# Epocah: 013/2000 | Loss: 0.1040 | Loss_freq: 0.0662 | Loss_ae: 0.0023 | kl_div 0.0354 | Worst_Loss: 0.0138 | Worst_Loss_freq: 0.0023 | Worst_Loss_ae: 0.0161 |
# Time elapsed: 0.86 min
# Epocah: 014/2000 | Loss: 0.1082 | Loss_freq: 0.0719 | Loss_ae: 0.0018 | kl_div 0.0345 | Worst_Loss: 0.0138 | Worst_Loss_freq: 0.0019 | Worst_Loss_ae: 0.0156 |
# Time elapsed: 0.92 min
# Epocah: 015/2000 | Loss: 0.1820 | Loss_freq: 0.1444 | Loss_ae: 0.0019 | kl_div 0.0358 | Worst_Loss: 0.0130 | Worst_Loss_freq: 0.0020 | Worst_Loss_ae: 0.0150 |
# Time elapsed: 0.98 min
# Epocah: 016/2000 | Loss: 0.1198 | Loss_freq: 0.0830 | Loss_ae: 0.0018 | kl_div 0.0349 | Worst_Loss: 0.0131 | Worst_Loss_freq: 0.0019 | Worst_Loss_ae: 0.0151 |
# Time elapsed: 1.04 min
# Epocah: 017/2000 | Loss: 0.1103 | Loss_freq: 0.0746 | Loss_ae: 0.0014 | kl_div 0.0343 | Worst_Loss: 0.0117 | Worst_Loss_freq: 0.0019 | Worst_Loss_ae: 0.0136 |
# Time elapsed: 1.10 min
# Epocah: 018/2000 | Loss: 0.0882 | Loss_freq: 0.0528 | Loss_ae: 0.0018 | kl_div 0.0336 | Worst_Loss: 0.0103 | Worst_Loss_freq: 0.0018 | Worst_Loss_ae: 0.0121 |
# Time elapsed: 1.16 min
# Epocah: 019/2000 | Loss: 0.0831 | Loss_freq: 0.0470 | Loss_ae: 0.0019 | kl_div 0.0342 | Worst_Loss: 0.0091 | Worst_Loss_freq: 0.0022 | Worst_Loss_ae: 0.0113 |
# Time elapsed: 1.22 min
# Epocah: 020/2000 | Loss: 0.0979 | Loss_freq: 0.0637 | Loss_ae: 0.0012 | kl_div 0.0330 | Worst_Loss: 0.0112 | Worst_Loss_freq: 0.0018 | Worst_Loss_ae: 0.0130 |
# Time elapsed: 1.28 min
# Epocah: 021/2000 | Loss: 0.1020 | Loss_freq: 0.0657 | Loss_ae: 0.0019 | kl_div 0.0344 | Worst_Loss: 0.0113 | Worst_Loss_freq: 0.0022 | Worst_Loss_ae: 0.0135 |
# Time elapsed: 1.35 min
# Epocah: 022/2000 | Loss: 0.1120 | Loss_freq: 0.0755 | Loss_ae: 0.0019 | kl_div 0.0346 | Worst_Loss: 0.0100 | Worst_Loss_freq: 0.0017 | Worst_Loss_ae: 0.0118 |
# Time elapsed: 1.41 min
# Epocah: 023/2000 | Loss: 0.0891 | Loss_freq: 0.0541 | Loss_ae: 0.0014 | kl_div 0.0337 | Worst_Loss: 0.0087 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0103 |
# Time elapsed: 1.47 min
# Epocah: 024/2000 | Loss: 0.1920 | Loss_freq: 0.1562 | Loss_ae: 0.0019 | kl_div 0.0340 | Worst_Loss: 0.0084 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0100 |
# Time elapsed: 1.53 min
# Epocah: 025/2000 | Loss: 0.1019 | Loss_freq: 0.0681 | Loss_ae: 0.0013 | kl_div 0.0325 | Worst_Loss: 0.0091 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0107 |
# Time elapsed: 1.59 min
# Epocah: 026/2000 | Loss: 0.0778 | Loss_freq: 0.0432 | Loss_ae: 0.0013 | kl_div 0.0333 | Worst_Loss: 0.0094 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0110 |
# Time elapsed: 1.65 min
# Epocah: 027/2000 | Loss: 0.1194 | Loss_freq: 0.0847 | Loss_ae: 0.0012 | kl_div 0.0335 | Worst_Loss: 0.0082 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0096 |
# Time elapsed: 1.71 min
# Epocah: 028/2000 | Loss: 0.0753 | Loss_freq: 0.0424 | Loss_ae: 0.0013 | kl_div 0.0316 | Worst_Loss: 0.0096 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0111 |
# Time elapsed: 1.77 min
# Epocah: 029/2000 | Loss: 0.0808 | Loss_freq: 0.0458 | Loss_ae: 0.0014 | kl_div 0.0336 | Worst_Loss: 0.0078 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0092 |
# Time elapsed: 1.84 min
# Epocah: 030/2000 | Loss: 0.0803 | Loss_freq: 0.0484 | Loss_ae: 0.0013 | kl_div 0.0306 | Worst_Loss: 0.0087 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0100 |
# Time elapsed: 1.90 min
# Epocah: 031/2000 | Loss: 0.0652 | Loss_freq: 0.0330 | Loss_ae: 0.0011 | kl_div 0.0311 | Worst_Loss: 0.0085 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0098 |
# Time elapsed: 1.96 min
# Epocah: 032/2000 | Loss: 0.0803 | Loss_freq: 0.0469 | Loss_ae: 0.0011 | kl_div 0.0323 | Worst_Loss: 0.0081 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0095 |
# Time elapsed: 2.02 min
# Epocah: 033/2000 | Loss: 0.0772 | Loss_freq: 0.0437 | Loss_ae: 0.0011 | kl_div 0.0324 | Worst_Loss: 0.0068 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0081 |
# Time elapsed: 2.08 min
# Epocah: 034/2000 | Loss: 0.1555 | Loss_freq: 0.1229 | Loss_ae: 0.0015 | kl_div 0.0312 | Worst_Loss: 0.0095 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0109 |
# Time elapsed: 2.14 min
# Epocah: 035/2000 | Loss: 0.2662 | Loss_freq: 0.2342 | Loss_ae: 0.0017 | kl_div 0.0304 | Worst_Loss: 0.0092 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0105 |
# Time elapsed: 2.20 min
# Epocah: 036/2000 | Loss: 0.1167 | Loss_freq: 0.0820 | Loss_ae: 0.0020 | kl_div 0.0327 | Worst_Loss: 0.0179 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0194 |
# Time elapsed: 2.26 min
# Epocah: 037/2000 | Loss: 0.0657 | Loss_freq: 0.0334 | Loss_ae: 0.0011 | kl_div 0.0312 | Worst_Loss: 0.0066 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0080 |
# Time elapsed: 2.33 min
# Epocah: 038/2000 | Loss: 0.0777 | Loss_freq: 0.0455 | Loss_ae: 0.0012 | kl_div 0.0309 | Worst_Loss: 0.0071 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0084 |
# Time elapsed: 2.39 min
# Epocah: 039/2000 | Loss: 0.0732 | Loss_freq: 0.0425 | Loss_ae: 0.0011 | kl_div 0.0295 | Worst_Loss: 0.0075 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0089 |
# Time elapsed: 2.45 min
# Epocah: 040/2000 | Loss: 0.0674 | Loss_freq: 0.0357 | Loss_ae: 0.0019 | kl_div 0.0298 | Worst_Loss: 0.0063 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0076 |
# Time elapsed: 2.51 min
# Epocah: 041/2000 | Loss: 0.0650 | Loss_freq: 0.0352 | Loss_ae: 0.0014 | kl_div 0.0285 | Worst_Loss: 0.0068 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0081 |
# Time elapsed: 2.57 min
# Epocah: 042/2000 | Loss: 0.0674 | Loss_freq: 0.0368 | Loss_ae: 0.0011 | kl_div 0.0295 | Worst_Loss: 0.0109 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0123 |
# Time elapsed: 2.63 min
# Epocah: 043/2000 | Loss: 0.1003 | Loss_freq: 0.0695 | Loss_ae: 0.0016 | kl_div 0.0293 | Worst_Loss: 0.0069 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0082 |
# Time elapsed: 2.70 min
# Epocah: 044/2000 | Loss: 0.0759 | Loss_freq: 0.0467 | Loss_ae: 0.0016 | kl_div 0.0277 | Worst_Loss: 0.0058 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0072 |
# Time elapsed: 2.76 min
# Epocah: 045/2000 | Loss: 0.2013 | Loss_freq: 0.1722 | Loss_ae: 0.0016 | kl_div 0.0276 | Worst_Loss: 0.0065 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0080 |
# Time elapsed: 2.82 min
# Epocah: 046/2000 | Loss: 0.0840 | Loss_freq: 0.0558 | Loss_ae: 0.0012 | kl_div 0.0270 | Worst_Loss: 0.0061 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0075 |
# Time elapsed: 2.88 min
# Epocah: 047/2000 | Loss: 0.0569 | Loss_freq: 0.0290 | Loss_ae: 0.0016 | kl_div 0.0263 | Worst_Loss: 0.0068 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0081 |
# Time elapsed: 2.94 min
# Epocah: 048/2000 | Loss: 0.0825 | Loss_freq: 0.0543 | Loss_ae: 0.0014 | kl_div 0.0268 | Worst_Loss: 0.0051 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0065 |
# Time elapsed: 3.00 min
# Epocah: 049/2000 | Loss: 0.0659 | Loss_freq: 0.0381 | Loss_ae: 0.0015 | kl_div 0.0263 | Worst_Loss: 0.0059 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0072 |
# Time elapsed: 3.06 min
# Epocah: 050/2000 | Loss: 0.0741 | Loss_freq: 0.0450 | Loss_ae: 0.0016 | kl_div 0.0276 | Worst_Loss: 0.0076 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0091 |
# Time elapsed: 3.12 min
# Epocah: 051/2000 | Loss: 0.0743 | Loss_freq: 0.0460 | Loss_ae: 0.0015 | kl_div 0.0268 | Worst_Loss: 0.0048 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0061 |
# Time elapsed: 3.18 min
# Epocah: 052/2000 | Loss: 0.0743 | Loss_freq: 0.0465 | Loss_ae: 0.0013 | kl_div 0.0265 | Worst_Loss: 0.0052 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0066 |
# Time elapsed: 3.25 min
# Epocah: 053/2000 | Loss: 0.0593 | Loss_freq: 0.0334 | Loss_ae: 0.0010 | kl_div 0.0250 | Worst_Loss: 0.0070 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0083 |
# Time elapsed: 3.31 min
# Epocah: 054/2000 | Loss: 0.0648 | Loss_freq: 0.0384 | Loss_ae: 0.0013 | kl_div 0.0251 | Worst_Loss: 0.0048 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0062 |
# Time elapsed: 3.37 min
# Epocah: 055/2000 | Loss: 0.0714 | Loss_freq: 0.0442 | Loss_ae: 0.0020 | kl_div 0.0252 | Worst_Loss: 0.0045 | Worst_Loss_freq: 0.0018 | Worst_Loss_ae: 0.0063 |
# Time elapsed: 3.43 min
# Epocah: 056/2000 | Loss: 0.1221 | Loss_freq: 0.0960 | Loss_ae: 0.0014 | kl_div 0.0247 | Worst_Loss: 0.0090 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0104 |
# Time elapsed: 3.49 min
# Epocah: 057/2000 | Loss: 0.0555 | Loss_freq: 0.0287 | Loss_ae: 0.0017 | kl_div 0.0251 | Worst_Loss: 0.0057 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0071 |
# Time elapsed: 3.55 min
# Epocah: 058/2000 | Loss: 0.0606 | Loss_freq: 0.0352 | Loss_ae: 0.0012 | kl_div 0.0242 | Worst_Loss: 0.0042 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0055 |
# Time elapsed: 3.61 min
# Epocah: 059/2000 | Loss: 0.0516 | Loss_freq: 0.0261 | Loss_ae: 0.0010 | kl_div 0.0245 | Worst_Loss: 0.0045 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0058 |
# Time elapsed: 3.68 min
# Epocah: 060/2000 | Loss: 0.0426 | Loss_freq: 0.0173 | Loss_ae: 0.0016 | kl_div 0.0236 | Worst_Loss: 0.0042 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0056 |
# Time elapsed: 3.74 min
# Epocah: 061/2000 | Loss: 0.0642 | Loss_freq: 0.0388 | Loss_ae: 0.0017 | kl_div 0.0237 | Worst_Loss: 0.0051 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0064 |
# Time elapsed: 3.80 min
# Epocah: 062/2000 | Loss: 0.0549 | Loss_freq: 0.0310 | Loss_ae: 0.0009 | kl_div 0.0230 | Worst_Loss: 0.0038 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0051 |
# Time elapsed: 3.86 min
# Epocah: 063/2000 | Loss: 0.0457 | Loss_freq: 0.0223 | Loss_ae: 0.0009 | kl_div 0.0225 | Worst_Loss: 0.0043 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0058 |
# Time elapsed: 3.92 min
# Epocah: 064/2000 | Loss: 0.0430 | Loss_freq: 0.0192 | Loss_ae: 0.0011 | kl_div 0.0226 | Worst_Loss: 0.0044 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0057 |
# Time elapsed: 3.98 min
# Epocah: 065/2000 | Loss: 0.0515 | Loss_freq: 0.0276 | Loss_ae: 0.0015 | kl_div 0.0225 | Worst_Loss: 0.0035 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0047 |
# Time elapsed: 4.04 min
# Epocah: 066/2000 | Loss: 0.0425 | Loss_freq: 0.0192 | Loss_ae: 0.0012 | kl_div 0.0221 | Worst_Loss: 0.0036 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0049 |
# Time elapsed: 4.11 min
# Epocah: 067/2000 | Loss: 0.0794 | Loss_freq: 0.0570 | Loss_ae: 0.0012 | kl_div 0.0212 | Worst_Loss: 0.0037 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0050 |
# Time elapsed: 4.17 min
# Epocah: 068/2000 | Loss: 0.0778 | Loss_freq: 0.0566 | Loss_ae: 0.0015 | kl_div 0.0197 | Worst_Loss: 0.0035 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0049 |
# Time elapsed: 4.23 min
# Epocah: 069/2000 | Loss: 0.0389 | Loss_freq: 0.0165 | Loss_ae: 0.0013 | kl_div 0.0211 | Worst_Loss: 0.0043 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0056 |
# Time elapsed: 4.29 min
# Epocah: 070/2000 | Loss: 0.0629 | Loss_freq: 0.0416 | Loss_ae: 0.0010 | kl_div 0.0202 | Worst_Loss: 0.0031 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0044 |
# Time elapsed: 4.35 min
# Epocah: 071/2000 | Loss: 0.0491 | Loss_freq: 0.0281 | Loss_ae: 0.0010 | kl_div 0.0199 | Worst_Loss: 0.0030 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0043 |
# Time elapsed: 4.41 min
# Epocah: 072/2000 | Loss: 0.0379 | Loss_freq: 0.0170 | Loss_ae: 0.0013 | kl_div 0.0196 | Worst_Loss: 0.0031 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0044 |
# Time elapsed: 4.47 min
# Epocah: 073/2000 | Loss: 0.0452 | Loss_freq: 0.0245 | Loss_ae: 0.0015 | kl_div 0.0192 | Worst_Loss: 0.0030 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0044 |
# Time elapsed: 4.53 min
# Epocah: 074/2000 | Loss: 0.0417 | Loss_freq: 0.0209 | Loss_ae: 0.0012 | kl_div 0.0197 | Worst_Loss: 0.0048 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0061 |
# Time elapsed: 4.60 min
# Epocah: 075/2000 | Loss: 0.0744 | Loss_freq: 0.0547 | Loss_ae: 0.0009 | kl_div 0.0188 | Worst_Loss: 0.0032 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0045 |
# Time elapsed: 4.66 min
# Epocah: 076/2000 | Loss: 0.0416 | Loss_freq: 0.0222 | Loss_ae: 0.0013 | kl_div 0.0181 | Worst_Loss: 0.0029 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0043 |
# Time elapsed: 4.72 min
# Epocah: 077/2000 | Loss: 0.0448 | Loss_freq: 0.0260 | Loss_ae: 0.0015 | kl_div 0.0173 | Worst_Loss: 0.0032 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0045 |
# Time elapsed: 4.78 min
# Epocah: 078/2000 | Loss: 0.0331 | Loss_freq: 0.0140 | Loss_ae: 0.0009 | kl_div 0.0182 | Worst_Loss: 0.0027 | Worst_Loss_freq: 0.0012 | Worst_Loss_ae: 0.0040 |
# Time elapsed: 4.84 min
# Epocah: 079/2000 | Loss: 0.0476 | Loss_freq: 0.0281 | Loss_ae: 0.0015 | kl_div 0.0181 | Worst_Loss: 0.0032 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0045 |
# Time elapsed: 4.90 min
# Epocah: 080/2000 | Loss: 0.0333 | Loss_freq: 0.0150 | Loss_ae: 0.0013 | kl_div 0.0170 | Worst_Loss: 0.0027 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0040 |
# Time elapsed: 4.96 min
# Epocah: 081/2000 | Loss: 0.0428 | Loss_freq: 0.0237 | Loss_ae: 0.0015 | kl_div 0.0176 | Worst_Loss: 0.0031 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0044 |
# Time elapsed: 5.03 min
# Epocah: 082/2000 | Loss: 0.0404 | Loss_freq: 0.0225 | Loss_ae: 0.0010 | kl_div 0.0169 | Worst_Loss: 0.0026 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0039 |
# Time elapsed: 5.09 min
# Epocah: 083/2000 | Loss: 0.0315 | Loss_freq: 0.0135 | Loss_ae: 0.0012 | kl_div 0.0168 | Worst_Loss: 0.0026 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0039 |
# Time elapsed: 5.15 min
# Epocah: 084/2000 | Loss: 0.0426 | Loss_freq: 0.0247 | Loss_ae: 0.0015 | kl_div 0.0164 | Worst_Loss: 0.0032 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0045 |
# Time elapsed: 5.21 min
# Epocah: 085/2000 | Loss: 0.0261 | Loss_freq: 0.0091 | Loss_ae: 0.0012 | kl_div 0.0158 | Worst_Loss: 0.0024 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0037 |
# Time elapsed: 5.27 min
# Epocah: 086/2000 | Loss: 0.0547 | Loss_freq: 0.0368 | Loss_ae: 0.0010 | kl_div 0.0168 | Worst_Loss: 0.0026 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0039 |
# Time elapsed: 5.33 min
# Epocah: 087/2000 | Loss: 0.0356 | Loss_freq: 0.0189 | Loss_ae: 0.0013 | kl_div 0.0154 | Worst_Loss: 0.0033 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0046 |
# Time elapsed: 5.39 min
# Epocah: 088/2000 | Loss: 0.0342 | Loss_freq: 0.0178 | Loss_ae: 0.0011 | kl_div 0.0153 | Worst_Loss: 0.0023 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0036 |
# Time elapsed: 5.45 min
# Epocah: 089/2000 | Loss: 0.0367 | Loss_freq: 0.0199 | Loss_ae: 0.0011 | kl_div 0.0156 | Worst_Loss: 0.0034 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0048 |
# Time elapsed: 5.52 min
# Epocah: 090/2000 | Loss: 0.0435 | Loss_freq: 0.0263 | Loss_ae: 0.0015 | kl_div 0.0157 | Worst_Loss: 0.0022 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0035 |
# Time elapsed: 5.58 min
# Epocah: 091/2000 | Loss: 0.0334 | Loss_freq: 0.0174 | Loss_ae: 0.0012 | kl_div 0.0147 | Worst_Loss: 0.0026 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0040 |
# Time elapsed: 5.64 min
# Epocah: 092/2000 | Loss: 0.0289 | Loss_freq: 0.0129 | Loss_ae: 0.0014 | kl_div 0.0147 | Worst_Loss: 0.0023 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0037 |
# Time elapsed: 5.70 min
# Epocah: 093/2000 | Loss: 0.0608 | Loss_freq: 0.0443 | Loss_ae: 0.0018 | kl_div 0.0147 | Worst_Loss: 0.0030 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0043 |
# Time elapsed: 5.76 min
# Epocah: 094/2000 | Loss: 0.0477 | Loss_freq: 0.0323 | Loss_ae: 0.0010 | kl_div 0.0143 | Worst_Loss: 0.0032 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0046 |
# Time elapsed: 5.82 min
# Epocah: 095/2000 | Loss: 0.0463 | Loss_freq: 0.0308 | Loss_ae: 0.0012 | kl_div 0.0144 | Worst_Loss: 0.0027 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0040 |
# Time elapsed: 5.88 min
# Epocah: 096/2000 | Loss: 0.0334 | Loss_freq: 0.0187 | Loss_ae: 0.0008 | kl_div 0.0139 | Worst_Loss: 0.0023 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0036 |
# Time elapsed: 5.95 min
# Epocah: 097/2000 | Loss: 0.0303 | Loss_freq: 0.0146 | Loss_ae: 0.0013 | kl_div 0.0145 | Worst_Loss: 0.0030 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0044 |
# Time elapsed: 6.01 min
# Epocah: 098/2000 | Loss: 0.0552 | Loss_freq: 0.0400 | Loss_ae: 0.0015 | kl_div 0.0137 | Worst_Loss: 0.0020 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0035 |
# Time elapsed: 6.07 min
# Epocah: 099/2000 | Loss: 0.0526 | Loss_freq: 0.0370 | Loss_ae: 0.0018 | kl_div 0.0138 | Worst_Loss: 0.0026 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0040 |
# Time elapsed: 6.13 min
# Epocah: 100/2000 | Loss: 0.0305 | Loss_freq: 0.0159 | Loss_ae: 0.0015 | kl_div 0.0130 | Worst_Loss: 0.0022 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0036 |
# Time elapsed: 6.19 min
# Epocah: 101/2000 | Loss: 0.0336 | Loss_freq: 0.0189 | Loss_ae: 0.0011 | kl_div 0.0136 | Worst_Loss: 0.0020 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 6.25 min
# Epocah: 102/2000 | Loss: 0.0253 | Loss_freq: 0.0104 | Loss_ae: 0.0010 | kl_div 0.0139 | Worst_Loss: 0.0020 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 6.31 min
# Epocah: 103/2000 | Loss: 0.0279 | Loss_freq: 0.0139 | Loss_ae: 0.0014 | kl_div 0.0126 | Worst_Loss: 0.0022 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0036 |
# Time elapsed: 6.38 min
# Epocah: 104/2000 | Loss: 0.0236 | Loss_freq: 0.0097 | Loss_ae: 0.0013 | kl_div 0.0126 | Worst_Loss: 0.0022 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0036 |
# Time elapsed: 6.44 min
# Epocah: 105/2000 | Loss: 0.0332 | Loss_freq: 0.0199 | Loss_ae: 0.0010 | kl_div 0.0123 | Worst_Loss: 0.0022 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0037 |
# Time elapsed: 6.50 min
# Epocah: 106/2000 | Loss: 0.0270 | Loss_freq: 0.0137 | Loss_ae: 0.0008 | kl_div 0.0125 | Worst_Loss: 0.0020 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 6.56 min
# Epocah: 107/2000 | Loss: 0.0250 | Loss_freq: 0.0109 | Loss_ae: 0.0012 | kl_div 0.0129 | Worst_Loss: 0.0020 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 6.62 min
# Epocah: 108/2000 | Loss: 0.0322 | Loss_freq: 0.0178 | Loss_ae: 0.0017 | kl_div 0.0126 | Worst_Loss: 0.0020 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0036 |
# Time elapsed: 6.68 min
# Epocah: 109/2000 | Loss: 0.0233 | Loss_freq: 0.0089 | Loss_ae: 0.0015 | kl_div 0.0130 | Worst_Loss: 0.0020 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 6.74 min
# Epocah: 110/2000 | Loss: 0.0249 | Loss_freq: 0.0110 | Loss_ae: 0.0011 | kl_div 0.0128 | Worst_Loss: 0.0020 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 6.81 min
# Epocah: 111/2000 | Loss: 0.0491 | Loss_freq: 0.0340 | Loss_ae: 0.0015 | kl_div 0.0135 | Worst_Loss: 0.0020 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 6.87 min
# Epocah: 112/2000 | Loss: 0.0317 | Loss_freq: 0.0180 | Loss_ae: 0.0013 | kl_div 0.0124 | Worst_Loss: 0.0022 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0035 |
# Time elapsed: 6.93 min
# Epocah: 113/2000 | Loss: 0.0238 | Loss_freq: 0.0105 | Loss_ae: 0.0012 | kl_div 0.0120 | Worst_Loss: 0.0019 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0035 |
# Time elapsed: 6.99 min
# Epocah: 114/2000 | Loss: 0.0386 | Loss_freq: 0.0245 | Loss_ae: 0.0014 | kl_div 0.0127 | Worst_Loss: 0.0020 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0035 |
# Time elapsed: 7.05 min
# Epocah: 115/2000 | Loss: 0.0255 | Loss_freq: 0.0122 | Loss_ae: 0.0015 | kl_div 0.0118 | Worst_Loss: 0.0020 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0035 |
# Time elapsed: 7.11 min
# Epocah: 116/2000 | Loss: 0.0416 | Loss_freq: 0.0272 | Loss_ae: 0.0019 | kl_div 0.0125 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 7.17 min
# Epocah: 117/2000 | Loss: 0.0244 | Loss_freq: 0.0120 | Loss_ae: 0.0009 | kl_div 0.0114 | Worst_Loss: 0.0019 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 7.24 min
# Epocah: 118/2000 | Loss: 0.0676 | Loss_freq: 0.0536 | Loss_ae: 0.0017 | kl_div 0.0124 | Worst_Loss: 0.0021 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0035 |
# Time elapsed: 7.30 min
# Epocah: 119/2000 | Loss: 0.0322 | Loss_freq: 0.0186 | Loss_ae: 0.0016 | kl_div 0.0121 | Worst_Loss: 0.0021 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0036 |
# Time elapsed: 7.36 min
# Epocah: 120/2000 | Loss: 0.0225 | Loss_freq: 0.0084 | Loss_ae: 0.0022 | kl_div 0.0119 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 7.42 min
# Epocah: 121/2000 | Loss: 0.0512 | Loss_freq: 0.0375 | Loss_ae: 0.0013 | kl_div 0.0124 | Worst_Loss: 0.0020 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 7.48 min
# Epocah: 122/2000 | Loss: 0.0280 | Loss_freq: 0.0148 | Loss_ae: 0.0013 | kl_div 0.0119 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 7.54 min
# Epocah: 123/2000 | Loss: 0.0388 | Loss_freq: 0.0256 | Loss_ae: 0.0016 | kl_div 0.0116 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 7.60 min
# Epocah: 124/2000 | Loss: 0.0249 | Loss_freq: 0.0124 | Loss_ae: 0.0012 | kl_div 0.0113 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 7.66 min
# Epocah: 125/2000 | Loss: 0.0449 | Loss_freq: 0.0315 | Loss_ae: 0.0018 | kl_div 0.0116 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 7.73 min
# Epocah: 126/2000 | Loss: 0.0220 | Loss_freq: 0.0095 | Loss_ae: 0.0015 | kl_div 0.0110 | Worst_Loss: 0.0022 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0036 |
# Time elapsed: 7.79 min
# Epocah: 127/2000 | Loss: 0.0216 | Loss_freq: 0.0088 | Loss_ae: 0.0015 | kl_div 0.0113 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 7.85 min
# Epocah: 128/2000 | Loss: 0.0312 | Loss_freq: 0.0191 | Loss_ae: 0.0014 | kl_div 0.0108 | Worst_Loss: 0.0020 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0035 |
# Time elapsed: 7.91 min
# Epocah: 129/2000 | Loss: 0.0380 | Loss_freq: 0.0248 | Loss_ae: 0.0018 | kl_div 0.0114 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 7.97 min
# Epocah: 130/2000 | Loss: 0.0331 | Loss_freq: 0.0197 | Loss_ae: 0.0011 | kl_div 0.0122 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 8.03 min
# Epocah: 131/2000 | Loss: 0.0276 | Loss_freq: 0.0152 | Loss_ae: 0.0012 | kl_div 0.0113 | Worst_Loss: 0.0019 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 8.09 min
# Epocah: 132/2000 | Loss: 0.0289 | Loss_freq: 0.0156 | Loss_ae: 0.0016 | kl_div 0.0117 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 8.15 min
# Epocah: 133/2000 | Loss: 0.0245 | Loss_freq: 0.0120 | Loss_ae: 0.0012 | kl_div 0.0114 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 8.22 min
# Epocah: 134/2000 | Loss: 0.0317 | Loss_freq: 0.0188 | Loss_ae: 0.0018 | kl_div 0.0111 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 8.28 min
# Epocah: 135/2000 | Loss: 0.0276 | Loss_freq: 0.0160 | Loss_ae: 0.0013 | kl_div 0.0103 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 8.34 min
# Epocah: 136/2000 | Loss: 0.0229 | Loss_freq: 0.0104 | Loss_ae: 0.0014 | kl_div 0.0110 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 8.40 min
# Epocah: 137/2000 | Loss: 0.0441 | Loss_freq: 0.0317 | Loss_ae: 0.0013 | kl_div 0.0111 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 8.46 min
# Epocah: 138/2000 | Loss: 0.0218 | Loss_freq: 0.0101 | Loss_ae: 0.0011 | kl_div 0.0105 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 8.52 min
# Epocah: 139/2000 | Loss: 0.0353 | Loss_freq: 0.0230 | Loss_ae: 0.0011 | kl_div 0.0112 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 8.58 min
# Epocah: 140/2000 | Loss: 0.0262 | Loss_freq: 0.0144 | Loss_ae: 0.0013 | kl_div 0.0105 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 8.65 min
# Epocah: 141/2000 | Loss: 0.0259 | Loss_freq: 0.0139 | Loss_ae: 0.0015 | kl_div 0.0105 | Worst_Loss: 0.0019 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 8.71 min
# Epocah: 142/2000 | Loss: 0.0215 | Loss_freq: 0.0096 | Loss_ae: 0.0014 | kl_div 0.0105 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 8.77 min
# Epocah: 143/2000 | Loss: 0.0316 | Loss_freq: 0.0205 | Loss_ae: 0.0015 | kl_div 0.0097 | Worst_Loss: 0.0019 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 8.83 min
# Epocah: 144/2000 | Loss: 0.0390 | Loss_freq: 0.0272 | Loss_ae: 0.0017 | kl_div 0.0101 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 8.89 min
# Epocah: 145/2000 | Loss: 0.0345 | Loss_freq: 0.0230 | Loss_ae: 0.0015 | kl_div 0.0100 | Worst_Loss: 0.0019 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0035 |
# Time elapsed: 8.95 min
# Epocah: 146/2000 | Loss: 0.0247 | Loss_freq: 0.0129 | Loss_ae: 0.0016 | kl_div 0.0102 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 9.01 min
# Epocah: 147/2000 | Loss: 0.0252 | Loss_freq: 0.0139 | Loss_ae: 0.0011 | kl_div 0.0103 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 9.07 min
# Epocah: 148/2000 | Loss: 0.0252 | Loss_freq: 0.0147 | Loss_ae: 0.0011 | kl_div 0.0094 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 9.14 min
# Epocah: 149/2000 | Loss: 0.0434 | Loss_freq: 0.0319 | Loss_ae: 0.0013 | kl_div 0.0102 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 9.20 min
# Epocah: 150/2000 | Loss: 0.0234 | Loss_freq: 0.0117 | Loss_ae: 0.0012 | kl_div 0.0105 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 9.26 min
# Epocah: 151/2000 | Loss: 0.0274 | Loss_freq: 0.0161 | Loss_ae: 0.0013 | kl_div 0.0099 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 9.32 min
# Epocah: 152/2000 | Loss: 0.0388 | Loss_freq: 0.0272 | Loss_ae: 0.0022 | kl_div 0.0095 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 9.38 min
# Epocah: 153/2000 | Loss: 0.0219 | Loss_freq: 0.0102 | Loss_ae: 0.0018 | kl_div 0.0099 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 9.44 min
# Epocah: 154/2000 | Loss: 0.0197 | Loss_freq: 0.0086 | Loss_ae: 0.0016 | kl_div 0.0095 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 9.50 min
# Epocah: 155/2000 | Loss: 0.0227 | Loss_freq: 0.0115 | Loss_ae: 0.0014 | kl_div 0.0098 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 9.57 min
# Epocah: 156/2000 | Loss: 0.0246 | Loss_freq: 0.0139 | Loss_ae: 0.0014 | kl_div 0.0093 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 9.63 min
# Epocah: 157/2000 | Loss: 0.0293 | Loss_freq: 0.0181 | Loss_ae: 0.0017 | kl_div 0.0096 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 9.69 min
# Epocah: 158/2000 | Loss: 0.0422 | Loss_freq: 0.0315 | Loss_ae: 0.0011 | kl_div 0.0096 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 9.75 min
# Epocah: 159/2000 | Loss: 0.0262 | Loss_freq: 0.0130 | Loss_ae: 0.0020 | kl_div 0.0111 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 9.81 min
# Epocah: 160/2000 | Loss: 0.0287 | Loss_freq: 0.0179 | Loss_ae: 0.0012 | kl_div 0.0096 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 9.87 min
# Epocah: 161/2000 | Loss: 0.0240 | Loss_freq: 0.0140 | Loss_ae: 0.0012 | kl_div 0.0088 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 9.93 min
# Epocah: 162/2000 | Loss: 0.0385 | Loss_freq: 0.0285 | Loss_ae: 0.0012 | kl_div 0.0088 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 9.99 min
# Epocah: 163/2000 | Loss: 0.0291 | Loss_freq: 0.0172 | Loss_ae: 0.0018 | kl_div 0.0101 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 10.06 min
# Epocah: 164/2000 | Loss: 0.0570 | Loss_freq: 0.0460 | Loss_ae: 0.0017 | kl_div 0.0094 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0017 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 10.12 min
# Epocah: 165/2000 | Loss: 0.0199 | Loss_freq: 0.0101 | Loss_ae: 0.0012 | kl_div 0.0086 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 10.18 min
# Epocah: 166/2000 | Loss: 0.0200 | Loss_freq: 0.0092 | Loss_ae: 0.0016 | kl_div 0.0091 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 10.24 min
# Epocah: 167/2000 | Loss: 0.0409 | Loss_freq: 0.0304 | Loss_ae: 0.0013 | kl_div 0.0092 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 10.30 min
# Epocah: 168/2000 | Loss: 0.0206 | Loss_freq: 0.0095 | Loss_ae: 0.0023 | kl_div 0.0088 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 10.36 min
# Epocah: 169/2000 | Loss: 0.0245 | Loss_freq: 0.0132 | Loss_ae: 0.0018 | kl_div 0.0095 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 10.42 min
# Epocah: 170/2000 | Loss: 0.0281 | Loss_freq: 0.0173 | Loss_ae: 0.0020 | kl_div 0.0088 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 10.48 min
# Epocah: 171/2000 | Loss: 0.0247 | Loss_freq: 0.0144 | Loss_ae: 0.0016 | kl_div 0.0087 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 10.55 min
# Epocah: 172/2000 | Loss: 0.0234 | Loss_freq: 0.0137 | Loss_ae: 0.0017 | kl_div 0.0080 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 10.61 min
# Epocah: 173/2000 | Loss: 0.0199 | Loss_freq: 0.0101 | Loss_ae: 0.0011 | kl_div 0.0087 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 10.67 min
# Epocah: 174/2000 | Loss: 0.0273 | Loss_freq: 0.0173 | Loss_ae: 0.0017 | kl_div 0.0083 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 10.73 min
# Epocah: 175/2000 | Loss: 0.0211 | Loss_freq: 0.0110 | Loss_ae: 0.0014 | kl_div 0.0087 | Worst_Loss: 0.0015 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 10.79 min
# Epocah: 176/2000 | Loss: 0.0220 | Loss_freq: 0.0126 | Loss_ae: 0.0013 | kl_div 0.0080 | Worst_Loss: 0.0019 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 10.85 min
# Epocah: 177/2000 | Loss: 0.0200 | Loss_freq: 0.0104 | Loss_ae: 0.0011 | kl_div 0.0085 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 10.91 min
# Epocah: 178/2000 | Loss: 0.0170 | Loss_freq: 0.0082 | Loss_ae: 0.0010 | kl_div 0.0077 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 10.98 min
# Epocah: 179/2000 | Loss: 0.0241 | Loss_freq: 0.0139 | Loss_ae: 0.0021 | kl_div 0.0082 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 11.04 min
# Epocah: 180/2000 | Loss: 0.0236 | Loss_freq: 0.0145 | Loss_ae: 0.0013 | kl_div 0.0078 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 11.10 min
# Epocah: 181/2000 | Loss: 0.0207 | Loss_freq: 0.0116 | Loss_ae: 0.0014 | kl_div 0.0077 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 11.16 min
# Epocah: 182/2000 | Loss: 0.0203 | Loss_freq: 0.0102 | Loss_ae: 0.0022 | kl_div 0.0079 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0017 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 11.22 min
# Epocah: 183/2000 | Loss: 0.0397 | Loss_freq: 0.0292 | Loss_ae: 0.0015 | kl_div 0.0090 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 11.28 min
# Epocah: 184/2000 | Loss: 0.0225 | Loss_freq: 0.0122 | Loss_ae: 0.0015 | kl_div 0.0088 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 11.34 min
# Epocah: 185/2000 | Loss: 0.0169 | Loss_freq: 0.0079 | Loss_ae: 0.0015 | kl_div 0.0075 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 11.41 min
# Epocah: 186/2000 | Loss: 0.0168 | Loss_freq: 0.0084 | Loss_ae: 0.0008 | kl_div 0.0075 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 11.47 min
# Epocah: 187/2000 | Loss: 0.0186 | Loss_freq: 0.0099 | Loss_ae: 0.0011 | kl_div 0.0077 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 11.53 min
# Epocah: 188/2000 | Loss: 0.0187 | Loss_freq: 0.0097 | Loss_ae: 0.0016 | kl_div 0.0074 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0017 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 11.59 min
# Epocah: 189/2000 | Loss: 0.0228 | Loss_freq: 0.0140 | Loss_ae: 0.0011 | kl_div 0.0077 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 11.65 min
# Epocah: 190/2000 | Loss: 0.0240 | Loss_freq: 0.0135 | Loss_ae: 0.0020 | kl_div 0.0085 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 11.71 min
# Epocah: 191/2000 | Loss: 0.0238 | Loss_freq: 0.0133 | Loss_ae: 0.0016 | kl_div 0.0089 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 11.77 min
# Epocah: 192/2000 | Loss: 0.0251 | Loss_freq: 0.0159 | Loss_ae: 0.0013 | kl_div 0.0079 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 11.83 min
# Epocah: 193/2000 | Loss: 0.0249 | Loss_freq: 0.0148 | Loss_ae: 0.0012 | kl_div 0.0089 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 11.90 min
# Epocah: 194/2000 | Loss: 0.0194 | Loss_freq: 0.0104 | Loss_ae: 0.0013 | kl_div 0.0077 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 11.96 min
# Epocah: 195/2000 | Loss: 0.0339 | Loss_freq: 0.0239 | Loss_ae: 0.0016 | kl_div 0.0083 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0017 | Worst_Loss_ae: 0.0035 |
# Time elapsed: 12.02 min
# Epocah: 196/2000 | Loss: 0.0322 | Loss_freq: 0.0233 | Loss_ae: 0.0011 | kl_div 0.0078 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 12.08 min
# Epocah: 197/2000 | Loss: 0.0204 | Loss_freq: 0.0103 | Loss_ae: 0.0016 | kl_div 0.0085 | Worst_Loss: 0.0015 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 12.14 min
# Epocah: 198/2000 | Loss: 0.0319 | Loss_freq: 0.0216 | Loss_ae: 0.0017 | kl_div 0.0086 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 12.20 min
# Epocah: 199/2000 | Loss: 0.0284 | Loss_freq: 0.0195 | Loss_ae: 0.0013 | kl_div 0.0076 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 12.26 min
# Epocah: 200/2000 | Loss: 0.0162 | Loss_freq: 0.0074 | Loss_ae: 0.0013 | kl_div 0.0076 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 12.32 min
# Epocah: 201/2000 | Loss: 0.0181 | Loss_freq: 0.0093 | Loss_ae: 0.0011 | kl_div 0.0076 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 12.39 min
# Epocah: 202/2000 | Loss: 0.0166 | Loss_freq: 0.0069 | Loss_ae: 0.0014 | kl_div 0.0083 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 12.45 min
# Epocah: 203/2000 | Loss: 0.0338 | Loss_freq: 0.0246 | Loss_ae: 0.0013 | kl_div 0.0078 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 12.51 min
# Epocah: 204/2000 | Loss: 0.0249 | Loss_freq: 0.0154 | Loss_ae: 0.0017 | kl_div 0.0078 | Worst_Loss: 0.0020 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0036 |
# Time elapsed: 12.57 min
# Epocah: 205/2000 | Loss: 0.0172 | Loss_freq: 0.0077 | Loss_ae: 0.0012 | kl_div 0.0083 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 12.63 min
# Epocah: 206/2000 | Loss: 0.0287 | Loss_freq: 0.0191 | Loss_ae: 0.0015 | kl_div 0.0081 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 12.69 min
# Epocah: 207/2000 | Loss: 0.0288 | Loss_freq: 0.0194 | Loss_ae: 0.0019 | kl_div 0.0076 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 12.75 min
# Epocah: 208/2000 | Loss: 0.0177 | Loss_freq: 0.0078 | Loss_ae: 0.0017 | kl_div 0.0082 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 12.82 min
# Epocah: 209/2000 | Loss: 0.0223 | Loss_freq: 0.0129 | Loss_ae: 0.0012 | kl_div 0.0083 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 12.88 min
# Epocah: 210/2000 | Loss: 0.0148 | Loss_freq: 0.0063 | Loss_ae: 0.0013 | kl_div 0.0072 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 12.94 min
# Epocah: 211/2000 | Loss: 0.0209 | Loss_freq: 0.0104 | Loss_ae: 0.0020 | kl_div 0.0086 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0018 | Worst_Loss_ae: 0.0035 |
# Time elapsed: 13.00 min
# Epocah: 212/2000 | Loss: 0.0367 | Loss_freq: 0.0279 | Loss_ae: 0.0012 | kl_div 0.0075 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 13.06 min
# Epocah: 213/2000 | Loss: 0.0220 | Loss_freq: 0.0122 | Loss_ae: 0.0015 | kl_div 0.0083 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 13.12 min
# Epocah: 214/2000 | Loss: 0.0183 | Loss_freq: 0.0083 | Loss_ae: 0.0017 | kl_div 0.0083 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 13.18 min
# Epocah: 215/2000 | Loss: 0.0301 | Loss_freq: 0.0209 | Loss_ae: 0.0016 | kl_div 0.0075 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 13.24 min
# Epocah: 216/2000 | Loss: 0.0292 | Loss_freq: 0.0188 | Loss_ae: 0.0018 | kl_div 0.0086 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 13.31 min
# Epocah: 217/2000 | Loss: 0.0297 | Loss_freq: 0.0199 | Loss_ae: 0.0017 | kl_div 0.0081 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 13.37 min
# Epocah: 218/2000 | Loss: 0.0224 | Loss_freq: 0.0126 | Loss_ae: 0.0017 | kl_div 0.0081 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 13.43 min
# Epocah: 219/2000 | Loss: 0.0299 | Loss_freq: 0.0196 | Loss_ae: 0.0021 | kl_div 0.0082 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 13.49 min
# Epocah: 220/2000 | Loss: 0.0187 | Loss_freq: 0.0097 | Loss_ae: 0.0016 | kl_div 0.0075 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 13.55 min
# Epocah: 221/2000 | Loss: 0.0220 | Loss_freq: 0.0123 | Loss_ae: 0.0017 | kl_div 0.0080 | Worst_Loss: 0.0015 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 13.61 min
# Epocah: 222/2000 | Loss: 0.0273 | Loss_freq: 0.0166 | Loss_ae: 0.0015 | kl_div 0.0092 | Worst_Loss: 0.0019 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 13.67 min
# Epocah: 223/2000 | Loss: 0.0194 | Loss_freq: 0.0091 | Loss_ae: 0.0019 | kl_div 0.0084 | Worst_Loss: 0.0015 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0030 |
# Time elapsed: 13.74 min
# Epocah: 224/2000 | Loss: 0.0409 | Loss_freq: 0.0311 | Loss_ae: 0.0012 | kl_div 0.0087 | Worst_Loss: 0.0023 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0039 |
# Time elapsed: 13.80 min
# Epocah: 225/2000 | Loss: 0.0234 | Loss_freq: 0.0139 | Loss_ae: 0.0014 | kl_div 0.0081 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0017 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 13.86 min
# Epocah: 226/2000 | Loss: 0.0160 | Loss_freq: 0.0071 | Loss_ae: 0.0013 | kl_div 0.0076 | Worst_Loss: 0.0015 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 13.92 min
# Epocah: 227/2000 | Loss: 0.0171 | Loss_freq: 0.0079 | Loss_ae: 0.0017 | kl_div 0.0074 | Worst_Loss: 0.0015 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0030 |
# Time elapsed: 13.98 min
# Epocah: 228/2000 | Loss: 0.0438 | Loss_freq: 0.0335 | Loss_ae: 0.0016 | kl_div 0.0087 | Worst_Loss: 0.0015 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0030 |
# Time elapsed: 14.04 min
# Epocah: 229/2000 | Loss: 0.0369 | Loss_freq: 0.0264 | Loss_ae: 0.0024 | kl_div 0.0081 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 14.10 min
# Epocah: 230/2000 | Loss: 0.0426 | Loss_freq: 0.0333 | Loss_ae: 0.0014 | kl_div 0.0079 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 14.16 min
# Epocah: 231/2000 | Loss: 0.0196 | Loss_freq: 0.0102 | Loss_ae: 0.0013 | kl_div 0.0081 | Worst_Loss: 0.0015 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0030 |
# Time elapsed: 14.23 min
# Epocah: 232/2000 | Loss: 0.0185 | Loss_freq: 0.0093 | Loss_ae: 0.0015 | kl_div 0.0077 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 14.29 min
# Epocah: 233/2000 | Loss: 0.0144 | Loss_freq: 0.0057 | Loss_ae: 0.0012 | kl_div 0.0075 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 14.35 min
# Epocah: 234/2000 | Loss: 0.0165 | Loss_freq: 0.0066 | Loss_ae: 0.0013 | kl_div 0.0086 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 14.41 min
# Epocah: 235/2000 | Loss: 0.0209 | Loss_freq: 0.0114 | Loss_ae: 0.0012 | kl_div 0.0083 | Worst_Loss: 0.0021 | Worst_Loss_freq: 0.0018 | Worst_Loss_ae: 0.0039 |
# Time elapsed: 14.47 min
# Epocah: 236/2000 | Loss: 0.0294 | Loss_freq: 0.0200 | Loss_ae: 0.0018 | kl_div 0.0076 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 14.53 min
# Epocah: 237/2000 | Loss: 0.0188 | Loss_freq: 0.0097 | Loss_ae: 0.0016 | kl_div 0.0075 | Worst_Loss: 0.0019 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0035 |
# Time elapsed: 14.59 min
# Epocah: 238/2000 | Loss: 0.0275 | Loss_freq: 0.0164 | Loss_ae: 0.0020 | kl_div 0.0091 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 14.66 min
# Epocah: 239/2000 | Loss: 0.0242 | Loss_freq: 0.0128 | Loss_ae: 0.0023 | kl_div 0.0092 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 14.72 min
# Epocah: 240/2000 | Loss: 0.0302 | Loss_freq: 0.0199 | Loss_ae: 0.0014 | kl_div 0.0088 | Worst_Loss: 0.0020 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 14.78 min
# Epocah: 241/2000 | Loss: 0.0261 | Loss_freq: 0.0159 | Loss_ae: 0.0022 | kl_div 0.0079 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0018 | Worst_Loss_ae: 0.0034 |
# Time elapsed: 14.84 min
# Epocah: 242/2000 | Loss: 0.0209 | Loss_freq: 0.0120 | Loss_ae: 0.0015 | kl_div 0.0075 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 14.90 min
# Epocah: 243/2000 | Loss: 0.0290 | Loss_freq: 0.0180 | Loss_ae: 0.0024 | kl_div 0.0086 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 14.96 min
# Epocah: 244/2000 | Loss: 0.0255 | Loss_freq: 0.0158 | Loss_ae: 0.0013 | kl_div 0.0084 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 15.02 min
# Epocah: 245/2000 | Loss: 0.0197 | Loss_freq: 0.0095 | Loss_ae: 0.0016 | kl_div 0.0085 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 15.09 min
# Epocah: 246/2000 | Loss: 0.0243 | Loss_freq: 0.0143 | Loss_ae: 0.0014 | kl_div 0.0087 | Worst_Loss: 0.0020 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0035 |
# Time elapsed: 15.15 min
# Epocah: 247/2000 | Loss: 0.0422 | Loss_freq: 0.0332 | Loss_ae: 0.0017 | kl_div 0.0073 | Worst_Loss: 0.0015 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0030 |
# Time elapsed: 15.21 min
# Epocah: 248/2000 | Loss: 0.0240 | Loss_freq: 0.0147 | Loss_ae: 0.0015 | kl_div 0.0078 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0017 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 15.27 min
# Epocah: 249/2000 | Loss: 0.0198 | Loss_freq: 0.0094 | Loss_ae: 0.0017 | kl_div 0.0087 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 15.33 min
# Epocah: 250/2000 | Loss: 0.0219 | Loss_freq: 0.0117 | Loss_ae: 0.0011 | kl_div 0.0091 | Worst_Loss: 0.0015 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0030 |
# Time elapsed: 15.39 min
# Epocah: 251/2000 | Loss: 0.0263 | Loss_freq: 0.0169 | Loss_ae: 0.0012 | kl_div 0.0081 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 15.45 min
# Epocah: 252/2000 | Loss: 0.0299 | Loss_freq: 0.0206 | Loss_ae: 0.0020 | kl_div 0.0073 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 15.51 min
# Epocah: 253/2000 | Loss: 0.0280 | Loss_freq: 0.0188 | Loss_ae: 0.0014 | kl_div 0.0078 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 15.58 min
# Epocah: 254/2000 | Loss: 0.0242 | Loss_freq: 0.0140 | Loss_ae: 0.0018 | kl_div 0.0084 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 15.64 min
# Epocah: 255/2000 | Loss: 0.0191 | Loss_freq: 0.0105 | Loss_ae: 0.0014 | kl_div 0.0073 | Worst_Loss: 0.0020 | Worst_Loss_freq: 0.0019 | Worst_Loss_ae: 0.0039 |
# Time elapsed: 15.70 min
# Epocah: 256/2000 | Loss: 0.0216 | Loss_freq: 0.0119 | Loss_ae: 0.0016 | kl_div 0.0081 | Worst_Loss: 0.0018 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 15.76 min
# Epocah: 257/2000 | Loss: 0.0312 | Loss_freq: 0.0222 | Loss_ae: 0.0013 | kl_div 0.0078 | Worst_Loss: 0.0015 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0030 |
# Time elapsed: 15.82 min
# Epocah: 258/2000 | Loss: 0.0179 | Loss_freq: 0.0092 | Loss_ae: 0.0013 | kl_div 0.0074 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 15.88 min
# Epocah: 259/2000 | Loss: 0.0195 | Loss_freq: 0.0099 | Loss_ae: 0.0016 | kl_div 0.0080 | Worst_Loss: 0.0015 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 15.94 min
# Epocah: 260/2000 | Loss: 0.0303 | Loss_freq: 0.0206 | Loss_ae: 0.0016 | kl_div 0.0082 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 16.00 min
# Epocah: 261/2000 | Loss: 0.0252 | Loss_freq: 0.0159 | Loss_ae: 0.0016 | kl_div 0.0077 | Worst_Loss: 0.0017 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0033 |
# Time elapsed: 16.07 min
# Epocah: 262/2000 | Loss: 0.0218 | Loss_freq: 0.0122 | Loss_ae: 0.0015 | kl_div 0.0081 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0016 | Worst_Loss_ae: 0.0032 |
# Time elapsed: 16.13 min
# Epocah: 263/2000 | Loss: 0.0138 | Loss_freq: 0.0044 | Loss_ae: 0.0015 | kl_div 0.0079 | Worst_Loss: 0.0016 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0031 |
# Time elapsed: 16.19 min
# ...
# Time elapsed: 117.19 min
# Epocah: 1915/2000 | Loss: 0.0136 | Loss_freq: 0.0027 | Loss_ae: 0.0016 | kl_div 0.0094 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 117.25 min
# Epocah: 1916/2000 | Loss: 0.0119 | Loss_freq: 0.0026 | Loss_ae: 0.0010 | kl_div 0.0083 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 117.31 min
# Epocah: 1917/2000 | Loss: 0.0142 | Loss_freq: 0.0037 | Loss_ae: 0.0018 | kl_div 0.0087 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 117.37 min
# Epocah: 1918/2000 | Loss: 0.0139 | Loss_freq: 0.0041 | Loss_ae: 0.0012 | kl_div 0.0087 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 117.44 min
# Epocah: 1919/2000 | Loss: 0.0115 | Loss_freq: 0.0020 | Loss_ae: 0.0012 | kl_div 0.0083 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 117.50 min
# Epocah: 1920/2000 | Loss: 0.0150 | Loss_freq: 0.0047 | Loss_ae: 0.0014 | kl_div 0.0089 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 117.56 min
# Epocah: 1921/2000 | Loss: 0.0153 | Loss_freq: 0.0050 | Loss_ae: 0.0010 | kl_div 0.0094 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 117.62 min
# Epocah: 1922/2000 | Loss: 0.0123 | Loss_freq: 0.0036 | Loss_ae: 0.0010 | kl_div 0.0077 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 117.68 min
# Epocah: 1923/2000 | Loss: 0.0128 | Loss_freq: 0.0036 | Loss_ae: 0.0011 | kl_div 0.0080 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 117.74 min
# Epocah: 1924/2000 | Loss: 0.0120 | Loss_freq: 0.0029 | Loss_ae: 0.0012 | kl_div 0.0079 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 117.80 min
# Epocah: 1925/2000 | Loss: 0.0148 | Loss_freq: 0.0046 | Loss_ae: 0.0014 | kl_div 0.0088 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 117.86 min
# Epocah: 1926/2000 | Loss: 0.0121 | Loss_freq: 0.0037 | Loss_ae: 0.0012 | kl_div 0.0072 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 117.93 min
# Epocah: 1927/2000 | Loss: 0.0126 | Loss_freq: 0.0031 | Loss_ae: 0.0015 | kl_div 0.0080 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 117.99 min
# Epocah: 1928/2000 | Loss: 0.0135 | Loss_freq: 0.0029 | Loss_ae: 0.0014 | kl_div 0.0093 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 118.05 min
# Epocah: 1929/2000 | Loss: 0.0165 | Loss_freq: 0.0041 | Loss_ae: 0.0015 | kl_div 0.0109 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 118.11 min
# Epocah: 1930/2000 | Loss: 0.0123 | Loss_freq: 0.0038 | Loss_ae: 0.0011 | kl_div 0.0074 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 118.17 min
# Epocah: 1931/2000 | Loss: 0.0157 | Loss_freq: 0.0054 | Loss_ae: 0.0015 | kl_div 0.0087 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 118.23 min
# Epocah: 1932/2000 | Loss: 0.0138 | Loss_freq: 0.0039 | Loss_ae: 0.0015 | kl_div 0.0084 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 118.29 min
# Epocah: 1933/2000 | Loss: 0.0133 | Loss_freq: 0.0037 | Loss_ae: 0.0010 | kl_div 0.0086 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 118.36 min
# Epocah: 1934/2000 | Loss: 0.0141 | Loss_freq: 0.0042 | Loss_ae: 0.0011 | kl_div 0.0087 | Worst_Loss: 0.0006 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 118.42 min
# Epocah: 1935/2000 | Loss: 0.0134 | Loss_freq: 0.0041 | Loss_ae: 0.0016 | kl_div 0.0077 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 118.48 min
# Epocah: 1936/2000 | Loss: 0.0163 | Loss_freq: 0.0038 | Loss_ae: 0.0020 | kl_div 0.0105 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 118.54 min
# Epocah: 1937/2000 | Loss: 0.0118 | Loss_freq: 0.0029 | Loss_ae: 0.0010 | kl_div 0.0079 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 118.60 min
# Epocah: 1938/2000 | Loss: 0.0180 | Loss_freq: 0.0045 | Loss_ae: 0.0017 | kl_div 0.0118 | Worst_Loss: 0.0007 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0020 |
# Time elapsed: 118.66 min
# Epocah: 1939/2000 | Loss: 0.0138 | Loss_freq: 0.0039 | Loss_ae: 0.0016 | kl_div 0.0083 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 118.72 min
# Epocah: 1940/2000 | Loss: 0.0129 | Loss_freq: 0.0039 | Loss_ae: 0.0011 | kl_div 0.0080 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 118.78 min
# Epocah: 1941/2000 | Loss: 0.0138 | Loss_freq: 0.0053 | Loss_ae: 0.0013 | kl_div 0.0072 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 118.85 min
# Epocah: 1942/2000 | Loss: 0.0140 | Loss_freq: 0.0040 | Loss_ae: 0.0014 | kl_div 0.0086 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 118.91 min
# Epocah: 1943/2000 | Loss: 0.0146 | Loss_freq: 0.0046 | Loss_ae: 0.0010 | kl_div 0.0090 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 118.97 min
# Epocah: 1944/2000 | Loss: 0.0123 | Loss_freq: 0.0033 | Loss_ae: 0.0014 | kl_div 0.0075 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 119.03 min
# Epocah: 1945/2000 | Loss: 0.0133 | Loss_freq: 0.0043 | Loss_ae: 0.0014 | kl_div 0.0076 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 119.09 min
# Epocah: 1946/2000 | Loss: 0.0120 | Loss_freq: 0.0034 | Loss_ae: 0.0012 | kl_div 0.0074 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 119.15 min
# Epocah: 1947/2000 | Loss: 0.0120 | Loss_freq: 0.0035 | Loss_ae: 0.0014 | kl_div 0.0070 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 119.21 min
# Epocah: 1948/2000 | Loss: 0.0141 | Loss_freq: 0.0039 | Loss_ae: 0.0014 | kl_div 0.0087 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 119.27 min
# Epocah: 1949/2000 | Loss: 0.0133 | Loss_freq: 0.0030 | Loss_ae: 0.0014 | kl_div 0.0089 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 119.34 min
# Epocah: 1950/2000 | Loss: 0.0130 | Loss_freq: 0.0033 | Loss_ae: 0.0018 | kl_div 0.0079 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 119.40 min
# Epocah: 1951/2000 | Loss: 0.0116 | Loss_freq: 0.0024 | Loss_ae: 0.0018 | kl_div 0.0075 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 119.46 min
# Epocah: 1952/2000 | Loss: 0.0131 | Loss_freq: 0.0037 | Loss_ae: 0.0016 | kl_div 0.0078 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 119.52 min
# Epocah: 1953/2000 | Loss: 0.0149 | Loss_freq: 0.0036 | Loss_ae: 0.0013 | kl_div 0.0099 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 119.58 min
# Epocah: 1954/2000 | Loss: 0.0138 | Loss_freq: 0.0040 | Loss_ae: 0.0015 | kl_div 0.0083 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 119.64 min
# Epocah: 1955/2000 | Loss: 0.0125 | Loss_freq: 0.0035 | Loss_ae: 0.0013 | kl_div 0.0077 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 119.70 min
# Epocah: 1956/2000 | Loss: 0.0133 | Loss_freq: 0.0043 | Loss_ae: 0.0015 | kl_div 0.0075 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 119.76 min
# Epocah: 1957/2000 | Loss: 0.0151 | Loss_freq: 0.0045 | Loss_ae: 0.0011 | kl_div 0.0094 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 119.83 min
# Epocah: 1958/2000 | Loss: 0.0133 | Loss_freq: 0.0035 | Loss_ae: 0.0017 | kl_div 0.0080 | Worst_Loss: 0.0006 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0020 |
# Time elapsed: 119.89 min
# Epocah: 1959/2000 | Loss: 0.0143 | Loss_freq: 0.0047 | Loss_ae: 0.0017 | kl_div 0.0079 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 119.95 min
# Epocah: 1960/2000 | Loss: 0.0124 | Loss_freq: 0.0024 | Loss_ae: 0.0019 | kl_div 0.0081 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 120.01 min
# Epocah: 1961/2000 | Loss: 0.0148 | Loss_freq: 0.0040 | Loss_ae: 0.0016 | kl_div 0.0092 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 120.07 min
# Epocah: 1962/2000 | Loss: 0.0136 | Loss_freq: 0.0049 | Loss_ae: 0.0012 | kl_div 0.0075 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 120.13 min
# Epocah: 1963/2000 | Loss: 0.0126 | Loss_freq: 0.0038 | Loss_ae: 0.0011 | kl_div 0.0077 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 120.19 min
# Epocah: 1964/2000 | Loss: 0.0150 | Loss_freq: 0.0045 | Loss_ae: 0.0014 | kl_div 0.0091 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 120.25 min
# Epocah: 1965/2000 | Loss: 0.0145 | Loss_freq: 0.0047 | Loss_ae: 0.0019 | kl_div 0.0079 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 120.32 min
# Epocah: 1966/2000 | Loss: 0.0132 | Loss_freq: 0.0035 | Loss_ae: 0.0013 | kl_div 0.0084 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 120.38 min
# Epocah: 1967/2000 | Loss: 0.0129 | Loss_freq: 0.0033 | Loss_ae: 0.0010 | kl_div 0.0086 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 120.44 min
# Epocah: 1968/2000 | Loss: 0.0131 | Loss_freq: 0.0029 | Loss_ae: 0.0012 | kl_div 0.0090 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 120.50 min
# Epocah: 1969/2000 | Loss: 0.0127 | Loss_freq: 0.0032 | Loss_ae: 0.0013 | kl_div 0.0082 | Worst_Loss: 0.0006 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 120.56 min
# Epocah: 1970/2000 | Loss: 0.0150 | Loss_freq: 0.0047 | Loss_ae: 0.0013 | kl_div 0.0090 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 120.62 min
# Epocah: 1971/2000 | Loss: 0.0139 | Loss_freq: 0.0034 | Loss_ae: 0.0011 | kl_div 0.0094 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0015 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 120.68 min
# Epocah: 1972/2000 | Loss: 0.0112 | Loss_freq: 0.0023 | Loss_ae: 0.0011 | kl_div 0.0077 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 120.74 min
# Epocah: 1973/2000 | Loss: 0.0133 | Loss_freq: 0.0031 | Loss_ae: 0.0018 | kl_div 0.0084 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 120.80 min
# Epocah: 1974/2000 | Loss: 0.0126 | Loss_freq: 0.0042 | Loss_ae: 0.0013 | kl_div 0.0072 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 120.87 min
# Epocah: 1975/2000 | Loss: 0.0158 | Loss_freq: 0.0052 | Loss_ae: 0.0014 | kl_div 0.0093 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0020 |
# Time elapsed: 120.93 min
# Epocah: 1976/2000 | Loss: 0.0147 | Loss_freq: 0.0046 | Loss_ae: 0.0011 | kl_div 0.0089 | Worst_Loss: 0.0006 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 120.99 min
# Epocah: 1977/2000 | Loss: 0.0122 | Loss_freq: 0.0036 | Loss_ae: 0.0010 | kl_div 0.0076 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 121.05 min
# Epocah: 1978/2000 | Loss: 0.0162 | Loss_freq: 0.0062 | Loss_ae: 0.0014 | kl_div 0.0086 | Worst_Loss: 0.0006 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 121.11 min
# Epocah: 1979/2000 | Loss: 0.0131 | Loss_freq: 0.0034 | Loss_ae: 0.0018 | kl_div 0.0079 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0016 |
# Time elapsed: 121.17 min
# Epocah: 1980/2000 | Loss: 0.0141 | Loss_freq: 0.0029 | Loss_ae: 0.0013 | kl_div 0.0099 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 121.23 min
# Epocah: 1981/2000 | Loss: 0.0146 | Loss_freq: 0.0035 | Loss_ae: 0.0013 | kl_div 0.0099 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 121.29 min
# Epocah: 1982/2000 | Loss: 0.0126 | Loss_freq: 0.0036 | Loss_ae: 0.0012 | kl_div 0.0079 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 121.35 min
# Epocah: 1983/2000 | Loss: 0.0151 | Loss_freq: 0.0036 | Loss_ae: 0.0014 | kl_div 0.0101 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 121.42 min
# Epocah: 1984/2000 | Loss: 0.0122 | Loss_freq: 0.0034 | Loss_ae: 0.0014 | kl_div 0.0074 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 121.48 min
# Epocah: 1985/2000 | Loss: 0.0133 | Loss_freq: 0.0037 | Loss_ae: 0.0012 | kl_div 0.0085 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 121.54 min
# Epocah: 1986/2000 | Loss: 0.0132 | Loss_freq: 0.0034 | Loss_ae: 0.0013 | kl_div 0.0085 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 121.60 min
# Epocah: 1987/2000 | Loss: 0.0120 | Loss_freq: 0.0031 | Loss_ae: 0.0014 | kl_div 0.0076 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 121.66 min
# Epocah: 1988/2000 | Loss: 0.0119 | Loss_freq: 0.0028 | Loss_ae: 0.0012 | kl_div 0.0079 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 121.72 min
# Epocah: 1989/2000 | Loss: 0.0148 | Loss_freq: 0.0031 | Loss_ae: 0.0015 | kl_div 0.0102 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 121.78 min
# Epocah: 1990/2000 | Loss: 0.0130 | Loss_freq: 0.0042 | Loss_ae: 0.0013 | kl_div 0.0075 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 121.85 min
# Epocah: 1991/2000 | Loss: 0.0130 | Loss_freq: 0.0031 | Loss_ae: 0.0013 | kl_div 0.0086 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 121.91 min
# Epocah: 1992/2000 | Loss: 0.0146 | Loss_freq: 0.0044 | Loss_ae: 0.0014 | kl_div 0.0089 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 121.97 min
# Epocah: 1993/2000 | Loss: 0.0142 | Loss_freq: 0.0048 | Loss_ae: 0.0015 | kl_div 0.0078 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 122.03 min
# Epocah: 1994/2000 | Loss: 0.0121 | Loss_freq: 0.0038 | Loss_ae: 0.0008 | kl_div 0.0075 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 122.09 min
# Epocah: 1995/2000 | Loss: 0.0144 | Loss_freq: 0.0033 | Loss_ae: 0.0014 | kl_div 0.0096 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0014 | Worst_Loss_ae: 0.0019 |
# Time elapsed: 122.15 min
# Epocah: 1996/2000 | Loss: 0.0118 | Loss_freq: 0.0029 | Loss_ae: 0.0013 | kl_div 0.0075 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 122.21 min
# Epocah: 1997/2000 | Loss: 0.0144 | Loss_freq: 0.0037 | Loss_ae: 0.0017 | kl_div 0.0089 | Worst_Loss: 0.0004 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 122.27 min
# Epocah: 1998/2000 | Loss: 0.0143 | Loss_freq: 0.0051 | Loss_ae: 0.0013 | kl_div 0.0079 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0017 |
# Time elapsed: 122.34 min
# Epocah: 1999/2000 | Loss: 0.0140 | Loss_freq: 0.0050 | Loss_ae: 0.0009 | kl_div 0.0080 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0013 | Worst_Loss_ae: 0.0018 |
# Time elapsed: 122.40 min
# Epocah: 2000/2000 | Loss: 0.0130 | Loss_freq: 0.0035 | Loss_ae: 0.0012 | kl_div 0.0082 | Worst_Loss: 0.0005 | Worst_Loss_freq: 0.0012 | Worst_Loss_ae: 0.0017 |
# Total Training Time: 122.40 min

# %% [markdown]
# ## Training

# %%
if SWEEP == 1:
    sweep_config = {
      "name" : "regression_lantent",
      "method" : "grid",
      "parameters" : {
        "dropout" : {
          "values" : [0.0, 0.05, 0.1, 0.15, 0.2, 0.25]
        }
      }
    }

    sweep_id = wandb.sweep(sweep_config)

    def train():
            config = wandb.config
            model = AutoEncoder(num_hiddens = num_hiddens, kernel_size = kernel_size, data_len = data_len, latent_dim = latent_dim, 
                                 regression_hidden = regression_hidden, dropout = config["dropout"])
            model.to(DEVICE)
            optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE) 
            train_autoencoder_v1(num_epochs=NUM_EPOCHS, model=model, 
                                    optimizer=optimizer, device=DEVICE, freq_mult = freq_mult,
                                    train_loader=train_loader,
                                    worst_case_loader = train_loader_worst,
                                    skip_epoch_stats=True,
                                    logging_interval=200, wandb = wandb)

    count = 6 # number of runs to execute
    wandb.agent(sweep_id, function=train, count=count)
if SWEEP == 0:
    from torchvision import models
    from torchsummary import summary
    set_all_seeds(RANDOM_SEED)

    model = AutoEncoder(num_hiddens = num_hiddens, kernel_size = kernel_size, data_len = data_len, latent_dim = latent_dim, regression_hidden = regression_hidden, dropout = dropout)
    model.to(DEVICE)

    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)  
    summary(model, (1,256), batch_size=-1, device='cuda')


    log_dict = train_autoencoder_v1(num_epochs=epoch, model=model, 
                                optimizer=optimizer, device=DEVICE, freq_mult = freq_mult,
                                train_loader=train_loader,
                                worst_case_loader = train_loader_worst,
                                skip_epoch_stats=True,
                                logging_interval=200, wandb = wandb)

# %% [markdown]
# ## Evaluation

# %%
model_type = "VAE"
plot_loss(log_dict, NUM_EPOCHS, model_type)
if latent_dim == 2:
    plot_latent_space_with_labels(train_loader, model, DEVICE)

# %%
plot_freq_loss(train_loader, model, DEVICE, model_type = model_type)

# %%
plot_freq_loss(train_loader_worst, model, DEVICE, model_type = model_type)

# %%
plot_cases(test_loader, model, DEVICE, model_type = model_type)

# %%
model_type = "VAE"
data = get_data_complete(filepath, model, "cpu", model_type = model_type)
#plot_frequencies(data, model)

# %%
plot_season(data, sr_mode=1)

# %%
torch.save(model, "VAE_final_latent_10_lorentz.modelAE")
